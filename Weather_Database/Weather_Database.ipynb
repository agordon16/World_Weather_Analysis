# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
import os
from config import weather_api_key

# %%
units = 'imperial'
url="http://api.openweathermap.org/data/2.5/weather?" + 'appid=' + weather_api_key + '&units=' + units

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | muros
# Processing Record 12 of Set 1 | bathsheba
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | krasnoselkup
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | port augusta
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | qaqortoq
# Processing Record 24 of Set 1 | meadow lake
# Processing Record 25 of Set 1 | auki
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | gharo
# Processing Record 31 of Set 1 | ciudad bolivar
# Processing Record 32 of Set 1 | havre-saint-pierre
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | atar
# Processing Record 35 of Set 1 | ikeda
# Processing Record 36 of Set 1 | muslyumovo
# Processing Record 37 of Set 1 | pisco
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | merauke
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | rocha
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | xiazhen
# Processing Record 44 of Set 1 | general roca
# Processing Record 45 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | hervey bay
# Processing Record 49 of Set 1 | caravelas
# Processing Record 50 of Set 1 | quang ngai
# Processing Record 1 of Set 2 | tarko-sale
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | play cu
# City not found. Skipping...
# Processing Record 5 of Set 2 | karratha
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | great yarmouth
# Processing Record 8 of Set 2 | turmalina
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | wick
# Processing Record 12 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 2 | touros
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | aguadilla
# Processing Record 16 of Set 2 | campina grande do sul
# Processing Record 17 of Set 2 | mosetse
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | kankon
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | ketchikan
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | ugoofaaru
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | omura
# Processing Record 27 of Set 2 | rawson
# Processing Record 28 of Set 2 | dumai
# Processing Record 29 of Set 2 | mauriti
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | nova vicosa
# Processing Record 33 of Set 2 | ulladulla
# Processing Record 34 of Set 2 | tucuman
# Processing Record 35 of Set 2 | aras
# Processing Record 36 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 2 | sattahip
# Processing Record 38 of Set 2 | qasigiannguit
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | rudbar
# Processing Record 41 of Set 2 | narsaq
# Processing Record 42 of Set 2 | salaspils
# Processing Record 43 of Set 2 | pueblo nuevo
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | esperance
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | sorong
# Processing Record 49 of Set 2 | libreville
# Processing Record 50 of Set 2 | curillo
# Processing Record 1 of Set 3 | anton lizardo
# Processing Record 2 of Set 3 | horizontina
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | northam
# Processing Record 5 of Set 3 | murgab
# Processing Record 6 of Set 3 | oktyabrskoye
# Processing Record 7 of Set 3 | leshukonskoye
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | high rock
# Processing Record 10 of Set 3 | broome
# Processing Record 11 of Set 3 | plouzane
# Processing Record 12 of Set 3 | san lawrenz
# Processing Record 13 of Set 3 | camacha
# Processing Record 14 of Set 3 | alghero
# Processing Record 15 of Set 3 | rio gallegos
# Processing Record 16 of Set 3 | mandleshwar
# Processing Record 17 of Set 3 | ilhabela
# Processing Record 18 of Set 3 | colares
# Processing Record 19 of Set 3 | usinsk
# Processing Record 20 of Set 3 | huarmey
# Processing Record 21 of Set 3 | baruun-urt
# Processing Record 22 of Set 3 | boca do acre
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | flinders
# Processing Record 25 of Set 3 | itacoatiara
# Processing Record 26 of Set 3 | kendari
# Processing Record 27 of Set 3 | todos santos
# Processing Record 28 of Set 3 | tarakan
# Processing Record 29 of Set 3 | vanimo
# Processing Record 30 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | kargasok
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | awbari
# Processing Record 34 of Set 3 | kieta
# Processing Record 35 of Set 3 | vila velha
# Processing Record 36 of Set 3 | bayburt
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | tasiilaq
# Processing Record 39 of Set 3 | maturin
# Processing Record 40 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 3 | raga
# Processing Record 42 of Set 3 | luba
# Processing Record 43 of Set 3 | babati
# Processing Record 44 of Set 3 | shache
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | saint george
# Processing Record 47 of Set 3 | mahebourg
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | clearlake
# Processing Record 50 of Set 3 | tortoli
# Processing Record 1 of Set 4 | hobart
# Processing Record 2 of Set 4 | chaiya
# Processing Record 3 of Set 4 | ishigaki
# Processing Record 4 of Set 4 | aykhal
# Processing Record 5 of Set 4 | pangnirtung
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | klaksvik
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | anloga
# Processing Record 10 of Set 4 | puerto leguizamo
# Processing Record 11 of Set 4 | tezu
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | mae sai
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | sisimiut
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | walvis bay
# Processing Record 18 of Set 4 | saldanha
# Processing Record 19 of Set 4 | progreso
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | palmer
# Processing Record 22 of Set 4 | quelimane
# Processing Record 23 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | bredasdorp
# Processing Record 26 of Set 4 | bluffton
# Processing Record 27 of Set 4 | nanortalik
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | tanjong karang
# City not found. Skipping...
# Processing Record 30 of Set 4 | gayny
# Processing Record 31 of Set 4 | laela
# Processing Record 32 of Set 4 | naze
# Processing Record 33 of Set 4 | kananga
# Processing Record 34 of Set 4 | ouesso
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | luderitz
# Processing Record 37 of Set 4 | zenzeli
# Processing Record 38 of Set 4 | shimizu
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | mindelo
# Processing Record 42 of Set 4 | kazerun
# Processing Record 43 of Set 4 | talaya
# Processing Record 44 of Set 4 | bojnurd
# Processing Record 45 of Set 4 | belem
# Processing Record 46 of Set 4 | hay river
# Processing Record 47 of Set 4 | gushikawa
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | marck
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | zmievka
# City not found. Skipping...
# Processing Record 3 of Set 5 | santarem
# Processing Record 4 of Set 5 | kiunga
# Processing Record 5 of Set 5 | tura
# Processing Record 6 of Set 5 | hualmay
# Processing Record 7 of Set 5 | vila franca do campo
# Processing Record 8 of Set 5 | otautau
# Processing Record 9 of Set 5 | neuquen
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 5 | mackay
# Processing Record 15 of Set 5 | zhigansk
# Processing Record 16 of Set 5 | saint-pierre
# Processing Record 17 of Set 5 | yerofey pavlovich
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | kandrian
# Processing Record 20 of Set 5 | coari
# Processing Record 21 of Set 5 | tromso
# Processing Record 22 of Set 5 | mandalgovi
# Processing Record 23 of Set 5 | ust-tsilma
# Processing Record 24 of Set 5 | flagstaff
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | victoria
# Processing Record 27 of Set 5 | hamilton
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | manikganj
# Processing Record 30 of Set 5 | salalah
# Processing Record 31 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 32 of Set 5 | alice springs
# Processing Record 33 of Set 5 | san patricio
# Processing Record 34 of Set 5 | port blair
# Processing Record 35 of Set 5 | belmonte
# Processing Record 36 of Set 5 | zyryanka
# Processing Record 37 of Set 5 | conde
# Processing Record 38 of Set 5 | heinola
# Processing Record 39 of Set 5 | buchanan
# Processing Record 40 of Set 5 | mehamn
# Processing Record 41 of Set 5 | zwedru
# Processing Record 42 of Set 5 | hobyo
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | komsomolskiy
# Processing Record 46 of Set 5 | sangar
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | los llanos de aridane
# Processing Record 49 of Set 5 | sarkand
# Processing Record 50 of Set 5 | sidney
# Processing Record 1 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 6 | lucapa
# Processing Record 3 of Set 6 | marsh harbour
# Processing Record 4 of Set 6 | nelson bay
# Processing Record 5 of Set 6 | te anau
# Processing Record 6 of Set 6 | makakilo city
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | tomatlan
# Processing Record 9 of Set 6 | jizan
# Processing Record 10 of Set 6 | mount isa
# Processing Record 11 of Set 6 | rathdrum
# Processing Record 12 of Set 6 | vilyuysk
# Processing Record 13 of Set 6 | henties bay
# Processing Record 14 of Set 6 | nhulunbuy
# Processing Record 15 of Set 6 | griffith
# Processing Record 16 of Set 6 | katsuura
# Processing Record 17 of Set 6 | college
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | dalbandin
# Processing Record 20 of Set 6 | myitkyina
# Processing Record 21 of Set 6 | basoko
# Processing Record 22 of Set 6 | guichicovi
# City not found. Skipping...
# Processing Record 23 of Set 6 | altay
# Processing Record 24 of Set 6 | tuatapere
# Processing Record 25 of Set 6 | mayo
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | pujehun
# Processing Record 28 of Set 6 | kloulklubed
# Processing Record 29 of Set 6 | giresun
# Processing Record 30 of Set 6 | arkhara
# Processing Record 31 of Set 6 | bomet
# Processing Record 32 of Set 6 | pochutla
# Processing Record 33 of Set 6 | kiama
# Processing Record 34 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 6 | noumea
# Processing Record 36 of Set 6 | manoel urbano
# Processing Record 37 of Set 6 | cap malheureux
# Processing Record 38 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | cayenne
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | quesnel
# Processing Record 43 of Set 6 | manacapuru
# Processing Record 44 of Set 6 | kalmunai
# Processing Record 45 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 6 | qandala
# Processing Record 47 of Set 6 | kununurra
# Processing Record 48 of Set 6 | kichera
# Processing Record 49 of Set 6 | east london
# Processing Record 50 of Set 6 | tuy hoa
# Processing Record 1 of Set 7 | maniitsoq
# Processing Record 2 of Set 7 | provideniya
# Processing Record 3 of Set 7 | dabat
# Processing Record 4 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 7 | araouane
# Processing Record 7 of Set 7 | talcahuano
# Processing Record 8 of Set 7 | joshimath
# Processing Record 9 of Set 7 | gorontalo
# Processing Record 10 of Set 7 | coolum beach
# Processing Record 11 of Set 7 | houlton
# Processing Record 12 of Set 7 | bellevue
# Processing Record 13 of Set 7 | kushiro
# Processing Record 14 of Set 7 | altamont
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | zhangjiakou
# Processing Record 17 of Set 7 | kedougou
# Processing Record 18 of Set 7 | sheffield lake
# Processing Record 19 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 20 of Set 7 | nome
# Processing Record 21 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 23 of Set 7 | huangnihe
# Processing Record 24 of Set 7 | balikpapan
# Processing Record 25 of Set 7 | samarai
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | esmeralda
# Processing Record 28 of Set 7 | humaita
# Processing Record 29 of Set 7 | vao
# Processing Record 30 of Set 7 | sodertalje
# City not found. Skipping...
# Processing Record 31 of Set 7 | oranjestad
# Processing Record 32 of Set 7 | ostrovnoy
# Processing Record 33 of Set 7 | isangel
# Processing Record 34 of Set 7 | clarence town
# Processing Record 35 of Set 7 | kirakira
# Processing Record 36 of Set 7 | sainte-maxime
# Processing Record 37 of Set 7 | praia da vitoria
# Processing Record 38 of Set 7 | punta cardon
# Processing Record 39 of Set 7 | tongliao
# Processing Record 40 of Set 7 | dunmore town
# Processing Record 41 of Set 7 | inuvik
# Processing Record 42 of Set 7 | hovd
# Processing Record 43 of Set 7 | adelaide
# Processing Record 44 of Set 7 | severo-kurilsk
# Processing Record 45 of Set 7 | san quintin
# Processing Record 46 of Set 7 | grindavik
# Processing Record 47 of Set 7 | adrar
# Processing Record 48 of Set 7 | codrington
# Processing Record 49 of Set 7 | san pedro
# Processing Record 50 of Set 7 | kupang
# Processing Record 1 of Set 8 | alice
# Processing Record 2 of Set 8 | tonota
# Processing Record 3 of Set 8 | rochegda
# Processing Record 4 of Set 8 | iqaluit
# Processing Record 5 of Set 8 | chapais
# Processing Record 6 of Set 8 | talakan
# Processing Record 7 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 8 of Set 8 | paka
# Processing Record 9 of Set 8 | bambanglipuro
# Processing Record 10 of Set 8 | inhambane
# Processing Record 11 of Set 8 | asosa
# Processing Record 12 of Set 8 | vilhena
# Processing Record 13 of Set 8 | cabo san lucas
# Processing Record 14 of Set 8 | awjilah
# Processing Record 15 of Set 8 | soyo
# Processing Record 16 of Set 8 | batemans bay
# Processing Record 17 of Set 8 | brandfort
# Processing Record 18 of Set 8 | valentin gomez farias
# Processing Record 19 of Set 8 | orikum
# Processing Record 20 of Set 8 | zhuhai
# Processing Record 21 of Set 8 | arrecife
# Processing Record 22 of Set 8 | tiksi
# Processing Record 23 of Set 8 | hope
# Processing Record 24 of Set 8 | lima
# Processing Record 25 of Set 8 | fosses
# Processing Record 26 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 27 of Set 8 | nabire
# Processing Record 28 of Set 8 | saint paul
# Processing Record 29 of Set 8 | leticia
# Processing Record 30 of Set 8 | ndende
# Processing Record 31 of Set 8 | sorland
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | baykit
# Processing Record 34 of Set 8 | lindi
# Processing Record 35 of Set 8 | gurgentepe
# Processing Record 36 of Set 8 | yakima
# Processing Record 37 of Set 8 | salinopolis
# Processing Record 38 of Set 8 | gamba
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | kralendijk
# Processing Record 41 of Set 8 | sur
# Processing Record 42 of Set 8 | tselinnoye
# Processing Record 43 of Set 8 | shelburne
# Processing Record 44 of Set 8 | gornozavodsk
# Processing Record 45 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 46 of Set 8 | lompoc
# Processing Record 47 of Set 8 | les cayes
# Processing Record 48 of Set 8 | ulaangom
# Processing Record 49 of Set 8 | gallup
# Processing Record 50 of Set 8 | lorengau
# Processing Record 1 of Set 9 | acapulco
# Processing Record 2 of Set 9 | faya
# Processing Record 3 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 4 of Set 9 | srednekolymsk
# Processing Record 5 of Set 9 | kota tinggi
# Processing Record 6 of Set 9 | jilib
# Processing Record 7 of Set 9 | nishihara
# Processing Record 8 of Set 9 | bristol
# Processing Record 9 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 9 | chegdomyn
# Processing Record 11 of Set 9 | metro
# Processing Record 12 of Set 9 | nouakchott
# Processing Record 13 of Set 9 | scarborough
# Processing Record 14 of Set 9 | ponta delgada
# Processing Record 15 of Set 9 | maloy
# Processing Record 16 of Set 9 | pringsewu
# Processing Record 17 of Set 9 | kasongo-lunda
# Processing Record 18 of Set 9 | eureka
# Processing Record 19 of Set 9 | cabatuan
# Processing Record 20 of Set 9 | copiapo
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | dauriya
# Processing Record 23 of Set 9 | yining
# Processing Record 24 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 9 | portland
# Processing Record 26 of Set 9 | reo
# Processing Record 27 of Set 9 | tirlyanskiy
# Processing Record 28 of Set 9 | abonnema
# Processing Record 29 of Set 9 | tyumentsevo
# Processing Record 30 of Set 9 | saint anthony
# Processing Record 31 of Set 9 | ardakan
# Processing Record 32 of Set 9 | guerrero negro
# Processing Record 33 of Set 9 | muhos
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | imeni poliny osipenko
# Processing Record 36 of Set 9 | clinton
# Processing Record 37 of Set 9 | trairi
# Processing Record 38 of Set 9 | andenes
# Processing Record 39 of Set 9 | meulaboh
# Processing Record 40 of Set 9 | tocopilla
# Processing Record 41 of Set 9 | upington
# Processing Record 42 of Set 9 | arica
# Processing Record 43 of Set 9 | lakes entrance
# Processing Record 44 of Set 9 | whitianga
# Processing Record 45 of Set 9 | kajaani
# Processing Record 46 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 9 | smithers
# Processing Record 48 of Set 9 | nisia floresta
# Processing Record 49 of Set 9 | gelemso
# Processing Record 50 of Set 9 | nemuro
# Processing Record 1 of Set 10 | pampierstad
# Processing Record 2 of Set 10 | okhotsk
# Processing Record 3 of Set 10 | la rioja
# Processing Record 4 of Set 10 | yaan
# Processing Record 5 of Set 10 | cockburn town
# Processing Record 6 of Set 10 | mantua
# Processing Record 7 of Set 10 | gosh
# Processing Record 8 of Set 10 | nouadhibou
# Processing Record 9 of Set 10 | aguimes
# Processing Record 10 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 10 | margate
# Processing Record 12 of Set 10 | vestmannaeyjar
# Processing Record 13 of Set 10 | najran
# Processing Record 14 of Set 10 | ixtapa
# Processing Record 15 of Set 10 | norsup
# Processing Record 16 of Set 10 | laguna
# Processing Record 17 of Set 10 | jacareacanga
# Processing Record 18 of Set 10 | ozernovskiy
# Processing Record 19 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 20 of Set 10 | saint-paul
# Processing Record 21 of Set 10 | deputatskiy
# Processing Record 22 of Set 10 | dingle
# Processing Record 23 of Set 10 | sheridan
# Processing Record 24 of Set 10 | wodonga
# Processing Record 25 of Set 10 | sao joao da barra
# Processing Record 26 of Set 10 | albania
# Processing Record 27 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 28 of Set 10 | sidi bu zayd
# City not found. Skipping...
# Processing Record 29 of Set 10 | omsukchan
# Processing Record 30 of Set 10 | balkanabat
# Processing Record 31 of Set 10 | tvoroyri
# Processing Record 32 of Set 10 | sinnamary
# Processing Record 33 of Set 10 | timra
# Processing Record 34 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 10 | sao filipe
# Processing Record 36 of Set 10 | verkhnetulomskiy
# Processing Record 37 of Set 10 | chilca
# Processing Record 38 of Set 10 | the valley
# Processing Record 39 of Set 10 | cam ranh
# Processing Record 40 of Set 10 | raudeberg
# Processing Record 41 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 10 | singaparna
# Processing Record 44 of Set 10 | lamar
# Processing Record 45 of Set 10 | kanker
# Processing Record 46 of Set 10 | port-gentil
# Processing Record 47 of Set 10 | stykkisholmur
# Processing Record 48 of Set 10 | burgeo
# Processing Record 49 of Set 10 | amguri
# Processing Record 50 of Set 10 | udachnyy
# Processing Record 1 of Set 11 | fortuna
# Processing Record 2 of Set 11 | payo
# Processing Record 3 of Set 11 | roald
# Processing Record 4 of Set 11 | virginia beach
# Processing Record 5 of Set 11 | gat
# Processing Record 6 of Set 11 | san carlos de bariloche
# Processing Record 7 of Set 11 | palana
# Processing Record 8 of Set 11 | kyzyl-suu
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | tilichiki
# Processing Record 11 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 11 | marienburg
# Processing Record 13 of Set 11 | taoudenni
# Processing Record 14 of Set 11 | porto walter
# Processing Record 15 of Set 11 | sao jose da coroa grande
# Processing Record 16 of Set 11 | sao gabriel da cachoeira
# Processing Record 17 of Set 11 | primorsk
# Processing Record 18 of Set 11 | vysokogornyy
# Processing Record 19 of Set 11 | marzuq
# Processing Record 20 of Set 11 | itarema
# Processing Record 21 of Set 11 | vengerovo
# Processing Record 22 of Set 11 | huanren
# Processing Record 23 of Set 11 | peoria
# Processing Record 24 of Set 11 | geraldton
# Processing Record 25 of Set 11 | khanion tou kokkini
# City not found. Skipping...
# Processing Record 26 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 11 | sambava
# Processing Record 28 of Set 11 | labrea
# Processing Record 29 of Set 11 | la ronge
# Processing Record 30 of Set 11 | fort nelson
# Processing Record 31 of Set 11 | hambantota
# Processing Record 32 of Set 11 | oriximina
# Processing Record 33 of Set 11 | airai
# Processing Record 34 of Set 11 | pierre
# Processing Record 35 of Set 11 | hutang
# Processing Record 36 of Set 11 | tekeli
# Processing Record 37 of Set 11 | coromandel
# Processing Record 38 of Set 11 | peqin
# Processing Record 39 of Set 11 | kenai
# Processing Record 40 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 11 | nerja
# Processing Record 42 of Set 11 | matagami
# Processing Record 43 of Set 11 | kaseda
# Processing Record 44 of Set 11 | coquimbo
# Processing Record 45 of Set 11 | leningradskiy
# Processing Record 46 of Set 11 | taltal
# Processing Record 47 of Set 11 | lazarev
# Processing Record 48 of Set 11 | semey
# Processing Record 49 of Set 11 | aksu
# Processing Record 50 of Set 11 | khani
# Processing Record 1 of Set 12 | nyurba
# Processing Record 2 of Set 12 | gawler
# Processing Record 3 of Set 12 | jalu
# Processing Record 4 of Set 12 | cachoeira do sul
# Processing Record 5 of Set 12 | takoradi
# Processing Record 6 of Set 12 | wageningen
# Processing Record 7 of Set 12 | tevaitoa
# Processing Record 8 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 9 of Set 12 | shingu
# Processing Record 10 of Set 12 | sibolga
# Processing Record 11 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 12 | lasa
# Processing Record 13 of Set 12 | mongo
# Processing Record 14 of Set 12 | namatanai
# Processing Record 15 of Set 12 | santa fe
# Processing Record 16 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 12 | mount gambier
# Processing Record 18 of Set 12 | emerald
# Processing Record 19 of Set 12 | chicama
# Processing Record 20 of Set 12 | brahmapuri
# City not found. Skipping...
# Processing Record 21 of Set 12 | robstown
# Processing Record 22 of Set 12 | vozhega
# Processing Record 23 of Set 12 | necochea
# Processing Record 24 of Set 12 | qui nhon
# Processing Record 25 of Set 12 | sistranda
# Processing Record 26 of Set 12 | flin flon
# Processing Record 27 of Set 12 | martapura
# Processing Record 28 of Set 12 | lakselv
# Processing Record 29 of Set 12 | comodoro rivadavia
# Processing Record 30 of Set 12 | puerto carreno
# Processing Record 31 of Set 12 | lexington
# Processing Record 32 of Set 12 | kendrapara
# Processing Record 33 of Set 12 | peniche
# Processing Record 34 of Set 12 | dunedin
# Processing Record 35 of Set 12 | puerto escondido
# Processing Record 36 of Set 12 | opuwo
# Processing Record 37 of Set 12 | mehran
# Processing Record 38 of Set 12 | huanuco
# Processing Record 39 of Set 12 | kangaatsiaq
# Processing Record 40 of Set 12 | kutum
# Processing Record 41 of Set 12 | hearst
# Processing Record 42 of Set 12 | beloha
# Processing Record 43 of Set 12 | venice
# Processing Record 44 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 12 | miraflores
# Processing Record 46 of Set 12 | marsa matruh
# Processing Record 47 of Set 12 | zhob
# Processing Record 48 of Set 12 | juneau
# Processing Record 49 of Set 12 | vondrozo
# Processing Record 50 of Set 12 | bilibino
# Processing Record 1 of Set 13 | monte patria
# Processing Record 2 of Set 13 | voznesenskoye
# Processing Record 3 of Set 13 | mbandaka
# Processing Record 4 of Set 13 | sorgues
# Processing Record 5 of Set 13 | boli
# Processing Record 6 of Set 13 | jinzhou
# Processing Record 7 of Set 13 | boralday
# Processing Record 8 of Set 13 | zhaodong
# Processing Record 9 of Set 13 | zabid
# Processing Record 10 of Set 13 | pingshan
# Processing Record 11 of Set 13 | duku
# Processing Record 12 of Set 13 | coahuayana
# Processing Record 13 of Set 13 | canavieiras
# Processing Record 14 of Set 13 | dhidhdhoo
# Processing Record 15 of Set 13 | vacaria
# Processing Record 16 of Set 13 | dudinka
# Processing Record 17 of Set 13 | bar-le-duc
# Processing Record 18 of Set 13 | locri
# Processing Record 19 of Set 13 | lata
# Processing Record 20 of Set 13 | broken hill
# Processing Record 21 of Set 13 | pacific grove
# Processing Record 22 of Set 13 | yumen
# Processing Record 23 of Set 13 | batagay-alyta
# Processing Record 24 of Set 13 | bolobo
# Processing Record 25 of Set 13 | mujiayingzi
# Processing Record 26 of Set 13 | westport
# Processing Record 27 of Set 13 | rongcheng
# Processing Record 28 of Set 13 | calama
# Processing Record 29 of Set 13 | port lincoln
# Processing Record 30 of Set 13 | mareeba
# Processing Record 31 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 32 of Set 13 | ilulissat
# Processing Record 33 of Set 13 | sampit
# Processing Record 34 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 13 | natal
# Processing Record 37 of Set 13 | ambilobe
# Processing Record 38 of Set 13 | lianzhou
# Processing Record 39 of Set 13 | beringovskiy
# Processing Record 40 of Set 13 | ravar
# Processing Record 41 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 13 | hirtshals
# Processing Record 43 of Set 13 | mombetsu
# Processing Record 44 of Set 13 | ewa beach
# Processing Record 45 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 13 | simao
# Processing Record 47 of Set 13 | belyy yar
# Processing Record 48 of Set 13 | khash
# Processing Record 49 of Set 13 | damghan
# Processing Record 50 of Set 13 | manta
# Processing Record 1 of Set 14 | flic en flac
# Processing Record 2 of Set 14 | saint-felicien
# Processing Record 3 of Set 14 | padang
# Processing Record 4 of Set 14 | whyalla
# Processing Record 5 of Set 14 | plyussa
# Processing Record 6 of Set 14 | bonthe
# Processing Record 7 of Set 14 | pinyug
# Processing Record 8 of Set 14 | clyde river
# Processing Record 9 of Set 14 | kabalo
# Processing Record 10 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 14 | banswada
# Processing Record 12 of Set 14 | victoria point
# Processing Record 13 of Set 14 | duartina
# Processing Record 14 of Set 14 | waipawa
# Processing Record 15 of Set 14 | lavumisa
# Processing Record 16 of Set 14 | muisne
# Processing Record 17 of Set 14 | mecca
# Processing Record 18 of Set 14 | healdsburg
# Processing Record 19 of Set 14 | santa cruz
# Processing Record 20 of Set 14 | santa cruz del norte
# Processing Record 21 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 14 | balkhash
# Processing Record 23 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 14 | hami
# Processing Record 25 of Set 14 | cravo norte
# Processing Record 26 of Set 14 | brighton
# Processing Record 27 of Set 14 | kysyl-syr
# Processing Record 28 of Set 14 | mariental
# Processing Record 29 of Set 14 | ongandjera
# Processing Record 30 of Set 14 | san cristobal
# Processing Record 31 of Set 14 | agara
# Processing Record 32 of Set 14 | morris
# Processing Record 33 of Set 14 | mwinilunga
# Processing Record 34 of Set 14 | pacifica
# Processing Record 35 of Set 14 | portlethen
# Processing Record 36 of Set 14 | husavik
# Processing Record 37 of Set 14 | vigrestad
# Processing Record 38 of Set 14 | ayan
# Processing Record 39 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 14 | tigil
# Processing Record 41 of Set 14 | lavrentiya
# Processing Record 42 of Set 14 | sioux lookout
# Processing Record 43 of Set 14 | wattegama
# Processing Record 44 of Set 14 | sitka
# Processing Record 45 of Set 14 | koygorodok
# Processing Record 46 of Set 14 | esna
# Processing Record 47 of Set 14 | raipur
# Processing Record 48 of Set 14 | thunder bay
# Processing Record 49 of Set 14 | pyaozerskiy
# Processing Record 50 of Set 14 | mandera
# Processing Record 1 of Set 15 | svetlyy
# Processing Record 2 of Set 15 | teya
# Processing Record 3 of Set 15 | sidi ali
# Processing Record 4 of Set 15 | nailsea
# Processing Record 5 of Set 15 | emilio carranza
# Processing Record 6 of Set 15 | egvekinot
# Processing Record 7 of Set 15 | bom jesus
# Processing Record 8 of Set 15 | insar
# Processing Record 9 of Set 15 | dubbo
# Processing Record 10 of Set 15 | batamshinskiy
# Processing Record 11 of Set 15 | vostochnyy
# Processing Record 12 of Set 15 | mendoza
# Processing Record 13 of Set 15 | asilah
# Processing Record 14 of Set 15 | nakhon thai
# Processing Record 15 of Set 15 | bacsalmas
# Processing Record 16 of Set 15 | tabou
# Processing Record 17 of Set 15 | nadym
# Processing Record 18 of Set 15 | ninghai
# Processing Record 19 of Set 15 | carutapera
# Processing Record 20 of Set 15 | mollendo
# Processing Record 21 of Set 15 | mount hagen
# Processing Record 22 of Set 15 | puerto baquerizo moreno
# Processing Record 23 of Set 15 | capao da canoa
# Processing Record 24 of Set 15 | tautira
# Processing Record 25 of Set 15 | itoman
# Processing Record 26 of Set 15 | tigzirt
# Processing Record 27 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 15 | severodvinsk
# Processing Record 29 of Set 15 | parabel
# Processing Record 30 of Set 15 | biak
# Processing Record 31 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 32 of Set 15 | narasannapeta
# Processing Record 33 of Set 15 | kawalu
# Processing Record 34 of Set 15 | tres picos
# Processing Record 35 of Set 15 | imbituba
# Processing Record 36 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 15 | ostersund
# Processing Record 38 of Set 15 | katsina
# Processing Record 39 of Set 15 | amapa
# Processing Record 40 of Set 15 | newport
# Processing Record 41 of Set 15 | hirara
# Processing Record 42 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 43 of Set 15 | kungurtug
# Processing Record 44 of Set 15 | avera
# Processing Record 45 of Set 15 | columbus
# Processing Record 46 of Set 15 | pathein
# Processing Record 47 of Set 15 | charagua
# Processing Record 48 of Set 15 | uzhur
# Processing Record 49 of Set 15 | lastoursville
# Processing Record 50 of Set 15 | varca
# Processing Record 1 of Set 16 | byron bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari   3.0707  172.7902     80.85        80          78
# 1   Tuktoyaktuk  69.4541 -133.0374    -18.40        76          75
# 2      Souillac -20.5167   57.5167     80.37        94          75
# 3        Avarua -21.2078 -159.7750     78.85        83          75
# 4      Hermanus -34.4187   19.2345     71.80        65          63
# 5  Puerto Ayora  -0.7393  -90.3518     77.56        88           4
# 6  Punta Arenas -53.1500  -70.9167     46.42        65         100
# 7       Ushuaia -54.8000  -68.3000     46.02        70         100
# 8   Yellowknife  62.4560 -114.3525    -29.58        75           0
# 9       Qaanaaq  77.4840  -69.3632    -13.86        65          87
#
#    Wind Speed Weather Description Country
# 0       12.82          light rain      KI
# 1       11.50          light snow      CA
# 2       26.46       moderate rain      MU
# 3       10.36          light rain      CK
# 4       15.10       broken clouds      ZA
# 5        5.01           clear sky      EC
# 6        6.91     overcast clouds      CL
# 7       14.97     overcast clouds      AR
# 8       11.50           clear sky      CA
# 9        8.16     overcast clouds      GL

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# %%
city_data_df=city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari      KI   3.0707  172.7902     80.85        80          78
# 1   Tuktoyaktuk      CA  69.4541 -133.0374    -18.40        76          75
# 2      Souillac      MU -20.5167   57.5167     80.37        94          75
# 3        Avarua      CK -21.2078 -159.7750     78.85        83          75
# 4      Hermanus      ZA -34.4187   19.2345     71.80        65          63
# 5  Puerto Ayora      EC  -0.7393  -90.3518     77.56        88           4
# 6  Punta Arenas      CL -53.1500  -70.9167     46.42        65         100
# 7       Ushuaia      AR -54.8000  -68.3000     46.02        70         100
# 8   Yellowknife      CA  62.4560 -114.3525    -29.58        75           0
# 9       Qaanaaq      GL  77.4840  -69.3632    -13.86        65          87
#
#    Wind Speed Weather Description
# 0       12.82          light rain
# 1       11.50          light snow
# 2       26.46       moderate rain
# 3       10.36          light rain
# 4       15.10       broken clouds
# 5        5.01           clear sky
# 6        6.91     overcast clouds
# 7       14.97     overcast clouds
# 8       11.50           clear sky
# 9        8.16     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
