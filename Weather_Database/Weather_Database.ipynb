# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../')
# Import the requests library.
import requests
# Import the API key.

from config import weather_api_key

# %%
units = 'imperial'
url="http://api.openweathermap.org/data/2.5/weather?" + 'appid=' + weather_api_key + '&units=' + units

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victor harbor
# Processing Record 2 of Set 1 | sobolevo
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | yenisehir
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | northam
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | matay
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | egvekinot
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | merauke
# Processing Record 16 of Set 1 | salalah
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | nawa
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | caravelas
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | ulladulla
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | bela
# Processing Record 27 of Set 1 | don sak
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | lugazi
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | lar
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | yaan
# Processing Record 36 of Set 1 | nahrin
# Processing Record 37 of Set 1 | oum hadjer
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | timra
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | amalapuram
# Processing Record 46 of Set 1 | jingdezhen
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | kalnciems
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | labuhan
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | banda aceh
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | coquimbo
# Processing Record 10 of Set 2 | da nang
# Processing Record 11 of Set 2 | dar es salaam
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | valle nacional
# Processing Record 14 of Set 2 | guymon
# Processing Record 15 of Set 2 | den helder
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | hambantota
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | talen
# Processing Record 20 of Set 2 | bahia blanca
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | fairbanks
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | saint-pierre
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | upington
# Processing Record 28 of Set 2 | santa rosa
# Processing Record 29 of Set 2 | luanda
# Processing Record 30 of Set 2 | tecoanapa
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | abha
# Processing Record 33 of Set 2 | troutdale
# Processing Record 34 of Set 2 | mahibadhoo
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | katakwi
# Processing Record 37 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 38 of Set 2 | beian
# Processing Record 39 of Set 2 | bambanglipuro
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | saryg-sep
# Processing Record 42 of Set 2 | bud
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | awbari
# Processing Record 45 of Set 2 | belmonte
# Processing Record 46 of Set 2 | fairview
# Processing Record 47 of Set 2 | gravdal
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | formosa do rio preto
# Processing Record 50 of Set 2 | mount isa
# Processing Record 1 of Set 3 | waipawa
# Processing Record 2 of Set 3 | mataura
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | hede
# Processing Record 5 of Set 3 | haines junction
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | sibolga
# Processing Record 10 of Set 3 | cervo
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | nizhniy tsasuchey
# Processing Record 13 of Set 3 | taltal
# Processing Record 14 of Set 3 | itarare
# Processing Record 15 of Set 3 | botwood
# Processing Record 16 of Set 3 | chiang khong
# Processing Record 17 of Set 3 | pagegiai
# Processing Record 18 of Set 3 | palmer
# Processing Record 19 of Set 3 | kamra
# Processing Record 20 of Set 3 | kimbe
# Processing Record 21 of Set 3 | nikolskoye
# Processing Record 22 of Set 3 | auki
# Processing Record 23 of Set 3 | ulaanbaatar
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | mildura
# Processing Record 28 of Set 3 | esso
# Processing Record 29 of Set 3 | evensk
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | itaituba
# Processing Record 33 of Set 3 | rio grande
# Processing Record 34 of Set 3 | lingao
# Processing Record 35 of Set 3 | mormugao
# Processing Record 36 of Set 3 | susehri
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 3 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | otsuki
# Processing Record 44 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 3 | taft
# Processing Record 47 of Set 3 | bose
# Processing Record 48 of Set 3 | swellendam
# Processing Record 49 of Set 3 | sao filipe
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 4 | domoni
# Processing Record 3 of Set 4 | foshan
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | ilo
# Processing Record 8 of Set 4 | bardiyah
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | pucallpa
# Processing Record 11 of Set 4 | urengoy
# Processing Record 12 of Set 4 | tashtagol
# Processing Record 13 of Set 4 | korla
# Processing Record 14 of Set 4 | fort nelson
# Processing Record 15 of Set 4 | kamaishi
# Processing Record 16 of Set 4 | flinders
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | bunia
# Processing Record 20 of Set 4 | praya
# Processing Record 21 of Set 4 | havre-saint-pierre
# Processing Record 22 of Set 4 | nenjiang
# Processing Record 23 of Set 4 | iskateley
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | shimoda
# Processing Record 26 of Set 4 | oranjestad
# Processing Record 27 of Set 4 | pochutla
# Processing Record 28 of Set 4 | kavieng
# Processing Record 29 of Set 4 | sakakah
# Processing Record 30 of Set 4 | aklavik
# Processing Record 31 of Set 4 | margate
# Processing Record 32 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | orsk
# Processing Record 35 of Set 4 | nome
# Processing Record 36 of Set 4 | te anau
# Processing Record 37 of Set 4 | westport
# Processing Record 38 of Set 4 | cabo rojo
# Processing Record 39 of Set 4 | ilulissat
# Processing Record 40 of Set 4 | miranda
# Processing Record 41 of Set 4 | rustam
# Processing Record 42 of Set 4 | kapaa
# Processing Record 43 of Set 4 | inirida
# Processing Record 44 of Set 4 | kuanshan
# City not found. Skipping...
# Processing Record 45 of Set 4 | klaksvik
# Processing Record 46 of Set 4 | sao joao da barra
# Processing Record 47 of Set 4 | gumla
# Processing Record 48 of Set 4 | luau
# Processing Record 49 of Set 4 | cayenne
# Processing Record 50 of Set 4 | atuona
# Processing Record 1 of Set 5 | hit
# Processing Record 2 of Set 5 | vila velha
# Processing Record 3 of Set 5 | weiden
# Processing Record 4 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 5 | kintampo
# Processing Record 6 of Set 5 | namibe
# Processing Record 7 of Set 5 | afua
# Processing Record 8 of Set 5 | kerema
# Processing Record 9 of Set 5 | varhaug
# Processing Record 10 of Set 5 | linxia
# Processing Record 11 of Set 5 | okakarara
# Processing Record 12 of Set 5 | urupes
# Processing Record 13 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 5 | abtenau
# Processing Record 15 of Set 5 | castro
# Processing Record 16 of Set 5 | alta floresta
# Processing Record 17 of Set 5 | jalu
# Processing Record 18 of Set 5 | shahrud
# Processing Record 19 of Set 5 | wundanyi
# Processing Record 20 of Set 5 | meulaboh
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | grants
# Processing Record 23 of Set 5 | kolkwitz
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | linkoping
# Processing Record 26 of Set 5 | talnakh
# Processing Record 27 of Set 5 | vigia
# Processing Record 28 of Set 5 | acajutla
# Processing Record 29 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 30 of Set 5 | iqaluit
# Processing Record 31 of Set 5 | ballina
# Processing Record 32 of Set 5 | ribeira grande
# Processing Record 33 of Set 5 | malartic
# Processing Record 34 of Set 5 | tibagi
# Processing Record 35 of Set 5 | kopyevo
# City not found. Skipping...
# Processing Record 36 of Set 5 | pagudpud
# Processing Record 37 of Set 5 | mount gambier
# Processing Record 38 of Set 5 | saskylakh
# Processing Record 39 of Set 5 | lincoln
# Processing Record 40 of Set 5 | amahai
# Processing Record 41 of Set 5 | pundaguitan
# Processing Record 42 of Set 5 | petrykiv
# Processing Record 43 of Set 5 | turayf
# Processing Record 44 of Set 5 | buarcos
# Processing Record 45 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 5 | acarau
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | xining
# Processing Record 49 of Set 5 | high level
# Processing Record 50 of Set 5 | ambon
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | hay river
# Processing Record 4 of Set 6 | qaanaaq
# Processing Record 5 of Set 6 | manta
# Processing Record 6 of Set 6 | buala
# Processing Record 7 of Set 6 | oksfjord
# Processing Record 8 of Set 6 | gurgan
# City not found. Skipping...
# Processing Record 9 of Set 6 | fukuma
# Processing Record 10 of Set 6 | manggar
# Processing Record 11 of Set 6 | moron
# Processing Record 12 of Set 6 | bayanday
# Processing Record 13 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 6 | millau
# Processing Record 15 of Set 6 | pisco
# Processing Record 16 of Set 6 | sao jose da coroa grande
# Processing Record 17 of Set 6 | maningrida
# Processing Record 18 of Set 6 | utinga
# Processing Record 19 of Set 6 | dicabisagan
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | khatanga
# Processing Record 22 of Set 6 | agropoli
# Processing Record 23 of Set 6 | severo-kurilsk
# Processing Record 24 of Set 6 | nouakchott
# Processing Record 25 of Set 6 | tiksi
# Processing Record 26 of Set 6 | yumen
# Processing Record 27 of Set 6 | jining
# Processing Record 28 of Set 6 | taicheng
# Processing Record 29 of Set 6 | port elizabeth
# Processing Record 30 of Set 6 | broken hill
# Processing Record 31 of Set 6 | puerto del rosario
# Processing Record 32 of Set 6 | tommot
# Processing Record 33 of Set 6 | cerritos
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | la romana
# Processing Record 36 of Set 6 | adiake
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | rawson
# Processing Record 39 of Set 6 | constitucion
# Processing Record 40 of Set 6 | staryy nadym
# Processing Record 41 of Set 6 | rio gallegos
# Processing Record 42 of Set 6 | livramento
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | north platte
# Processing Record 45 of Set 6 | nangomba
# Processing Record 46 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 6 | kununurra
# Processing Record 48 of Set 6 | luderitz
# Processing Record 49 of Set 6 | oksovskiy
# Processing Record 50 of Set 6 | mokrous
# Processing Record 1 of Set 7 | najran
# Processing Record 2 of Set 7 | pozo colorado
# Processing Record 3 of Set 7 | magistralnyy
# Processing Record 4 of Set 7 | acapulco
# Processing Record 5 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 7 | aden
# Processing Record 7 of Set 7 | stettler
# Processing Record 8 of Set 7 | nazarovo
# Processing Record 9 of Set 7 | kailua
# Processing Record 10 of Set 7 | byron bay
# Processing Record 11 of Set 7 | kodinsk
# Processing Record 12 of Set 7 | manokwari
# Processing Record 13 of Set 7 | corinto
# Processing Record 14 of Set 7 | husavik
# Processing Record 15 of Set 7 | orlovka
# Processing Record 16 of Set 7 | dengfeng
# Processing Record 17 of Set 7 | middle island
# Processing Record 18 of Set 7 | anadyr
# Processing Record 19 of Set 7 | chicama
# Processing Record 20 of Set 7 | cabo san lucas
# Processing Record 21 of Set 7 | saint-joseph
# Processing Record 22 of Set 7 | leshukonskoye
# Processing Record 23 of Set 7 | ylivieska
# Processing Record 24 of Set 7 | kangaatsiaq
# Processing Record 25 of Set 7 | bereznik
# Processing Record 26 of Set 7 | nikolayevsk-na-amure
# Processing Record 27 of Set 7 | sept-iles
# Processing Record 28 of Set 7 | vestmanna
# Processing Record 29 of Set 7 | sibu
# Processing Record 30 of Set 7 | kandrian
# Processing Record 31 of Set 7 | bilma
# Processing Record 32 of Set 7 | greenfield
# Processing Record 33 of Set 7 | alofi
# Processing Record 34 of Set 7 | los llanos de aridane
# Processing Record 35 of Set 7 | bowen
# Processing Record 36 of Set 7 | pangnirtung
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | llangefni
# Processing Record 39 of Set 7 | san quintin
# Processing Record 40 of Set 7 | ayna
# Processing Record 41 of Set 7 | dinga
# Processing Record 42 of Set 7 | udachnyy
# Processing Record 43 of Set 7 | venice
# Processing Record 44 of Set 7 | beruni
# City not found. Skipping...
# Processing Record 45 of Set 7 | port hardy
# Processing Record 46 of Set 7 | kushmurun
# Processing Record 47 of Set 7 | yazoo city
# Processing Record 48 of Set 7 | kawalu
# Processing Record 49 of Set 7 | ascension
# Processing Record 50 of Set 7 | cidreira
# Processing Record 1 of Set 8 | fortuna foothills
# Processing Record 2 of Set 8 | koumac
# Processing Record 3 of Set 8 | provideniya
# Processing Record 4 of Set 8 | magadan
# Processing Record 5 of Set 8 | casper
# Processing Record 6 of Set 8 | san cristobal
# Processing Record 7 of Set 8 | quatre cocos
# Processing Record 8 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 8 | kahului
# Processing Record 10 of Set 8 | the valley
# Processing Record 11 of Set 8 | glenwood springs
# Processing Record 12 of Set 8 | guarapari
# Processing Record 13 of Set 8 | fez
# Processing Record 14 of Set 8 | berlevag
# Processing Record 15 of Set 8 | malakal
# Processing Record 16 of Set 8 | kashi
# Processing Record 17 of Set 8 | puerto escondido
# Processing Record 18 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 8 | codrington
# Processing Record 20 of Set 8 | khandbari
# Processing Record 21 of Set 8 | shingu
# Processing Record 22 of Set 8 | skjervoy
# Processing Record 23 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 8 | chipata
# Processing Record 25 of Set 8 | soyo
# Processing Record 26 of Set 8 | kotma
# Processing Record 27 of Set 8 | aschersleben
# Processing Record 28 of Set 8 | kozhanka
# Processing Record 29 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 31 of Set 8 | portadown
# Processing Record 32 of Set 8 | vallenar
# Processing Record 33 of Set 8 | casino
# Processing Record 34 of Set 8 | mar del plata
# Processing Record 35 of Set 8 | mounana
# Processing Record 36 of Set 8 | omboue
# Processing Record 37 of Set 8 | san patricio
# Processing Record 38 of Set 8 | lorengau
# Processing Record 39 of Set 8 | tamworth
# Processing Record 40 of Set 8 | lucapa
# Processing Record 41 of Set 8 | miri
# Processing Record 42 of Set 8 | redlands
# Processing Record 43 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 44 of Set 8 | yar-sale
# Processing Record 45 of Set 8 | maurawan
# Processing Record 46 of Set 8 | tuatapere
# Processing Record 47 of Set 8 | san pedro
# Processing Record 48 of Set 8 | baishishan
# Processing Record 49 of Set 8 | bukama
# Processing Record 50 of Set 8 | tourlaville
# Processing Record 1 of Set 9 | eureka
# Processing Record 2 of Set 9 | gillette
# Processing Record 3 of Set 9 | mount pleasant
# Processing Record 4 of Set 9 | shumyachi
# Processing Record 5 of Set 9 | adrar
# Processing Record 6 of Set 9 | buraydah
# Processing Record 7 of Set 9 | lagoa
# Processing Record 8 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 9 | marienburg
# Processing Record 10 of Set 9 | chama
# Processing Record 11 of Set 9 | tateyama
# Processing Record 12 of Set 9 | sisimiut
# Processing Record 13 of Set 9 | gazanjyk
# Processing Record 14 of Set 9 | bronnoysund
# Processing Record 15 of Set 9 | tigil
# Processing Record 16 of Set 9 | nestorion
# City not found. Skipping...
# Processing Record 17 of Set 9 | tianpeng
# Processing Record 18 of Set 9 | abu zabad
# Processing Record 19 of Set 9 | megion
# Processing Record 20 of Set 9 | garden city
# Processing Record 21 of Set 9 | alice springs
# Processing Record 22 of Set 9 | salinopolis
# Processing Record 23 of Set 9 | geraldton
# Processing Record 24 of Set 9 | vostok
# Processing Record 25 of Set 9 | puerto baquerizo moreno
# Processing Record 26 of Set 9 | baghdad
# Processing Record 27 of Set 9 | mporokoso
# Processing Record 28 of Set 9 | okhotsk
# Processing Record 29 of Set 9 | zaria
# Processing Record 30 of Set 9 | virginia beach
# Processing Record 31 of Set 9 | port macquarie
# Processing Record 32 of Set 9 | gushikawa
# Processing Record 33 of Set 9 | miles city
# Processing Record 34 of Set 9 | necochea
# Processing Record 35 of Set 9 | doha
# Processing Record 36 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 9 | ermelo
# Processing Record 38 of Set 9 | piacabucu
# Processing Record 39 of Set 9 | sitka
# Processing Record 40 of Set 9 | tiarei
# Processing Record 41 of Set 9 | esperance
# Processing Record 42 of Set 9 | gandajika
# Processing Record 43 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 9 | laguna
# Processing Record 45 of Set 9 | abu kamal
# Processing Record 46 of Set 9 | rosia
# Processing Record 47 of Set 9 | ixtapa
# Processing Record 48 of Set 9 | machali
# Processing Record 49 of Set 9 | serebryanyy bor
# Processing Record 50 of Set 9 | chabahar
# Processing Record 1 of Set 10 | vao
# Processing Record 2 of Set 10 | ambagarh chauki
# Processing Record 3 of Set 10 | avera
# Processing Record 4 of Set 10 | saint-leu
# Processing Record 5 of Set 10 | poum
# Processing Record 6 of Set 10 | tezu
# Processing Record 7 of Set 10 | san policarpo
# Processing Record 8 of Set 10 | marolambo
# Processing Record 9 of Set 10 | sur
# Processing Record 10 of Set 10 | mahebourg
# Processing Record 11 of Set 10 | dubuque
# Processing Record 12 of Set 10 | strezhevoy
# Processing Record 13 of Set 10 | rolleston
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | sioux lookout
# Processing Record 16 of Set 10 | lydenburg
# Processing Record 17 of Set 10 | takoradi
# Processing Record 18 of Set 10 | faya
# Processing Record 19 of Set 10 | carauari
# Processing Record 20 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 21 of Set 10 | dingle
# Processing Record 22 of Set 10 | katav-ivanovsk
# Processing Record 23 of Set 10 | richards bay
# Processing Record 24 of Set 10 | atambua
# Processing Record 25 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 26 of Set 10 | yamada
# Processing Record 27 of Set 10 | batouri
# Processing Record 28 of Set 10 | slave lake
# Processing Record 29 of Set 10 | onega
# Processing Record 30 of Set 10 | plouzane
# Processing Record 31 of Set 10 | zhigalovo
# Processing Record 32 of Set 10 | saint anthony
# Processing Record 33 of Set 10 | naze
# Processing Record 34 of Set 10 | goya
# Processing Record 35 of Set 10 | ossora
# Processing Record 36 of Set 10 | lakes entrance
# Processing Record 37 of Set 10 | mopti
# Processing Record 38 of Set 10 | katsuura
# Processing Record 39 of Set 10 | hamilton
# Processing Record 40 of Set 10 | bertoua
# Processing Record 41 of Set 10 | sangar
# Processing Record 42 of Set 10 | chimbote
# Processing Record 43 of Set 10 | labytnangi
# Processing Record 44 of Set 10 | portland
# Processing Record 45 of Set 10 | boende
# Processing Record 46 of Set 10 | iberia
# Processing Record 47 of Set 10 | kovylkino
# Processing Record 48 of Set 10 | jaisalmer
# Processing Record 49 of Set 10 | kungurtug
# Processing Record 50 of Set 10 | alamosa
# Processing Record 1 of Set 11 | umm lajj
# Processing Record 2 of Set 11 | souillac
# Processing Record 3 of Set 11 | port hawkesbury
# Processing Record 4 of Set 11 | half moon bay
# Processing Record 5 of Set 11 | honningsvag
# Processing Record 6 of Set 11 | pedernales
# Processing Record 7 of Set 11 | tombouctou
# Processing Record 8 of Set 11 | ambulu
# Processing Record 9 of Set 11 | athy
# Processing Record 10 of Set 11 | goderich
# Processing Record 11 of Set 11 | sfantu gheorghe
# Processing Record 12 of Set 11 | qianan
# Processing Record 13 of Set 11 | salisbury
# Processing Record 14 of Set 11 | moree
# Processing Record 15 of Set 11 | oussouye
# Processing Record 16 of Set 11 | uyovu
# Processing Record 17 of Set 11 | coruche
# Processing Record 18 of Set 11 | ugoofaaru
# Processing Record 19 of Set 11 | walvis bay
# Processing Record 20 of Set 11 | athabasca
# Processing Record 21 of Set 11 | luba
# Processing Record 22 of Set 11 | comodoro rivadavia
# Processing Record 23 of Set 11 | liku
# Processing Record 24 of Set 11 | dumka
# Processing Record 25 of Set 11 | peterhead
# Processing Record 26 of Set 11 | mamallapuram
# Processing Record 27 of Set 11 | adana
# Processing Record 28 of Set 11 | praia
# Processing Record 29 of Set 11 | ponferrada
# Processing Record 30 of Set 11 | mackenzie
# Processing Record 31 of Set 11 | cukai
# Processing Record 32 of Set 11 | gualaquiza
# Processing Record 33 of Set 11 | cairns
# Processing Record 34 of Set 11 | zykovo
# Processing Record 35 of Set 11 | namatanai
# Processing Record 36 of Set 11 | arman
# Processing Record 37 of Set 11 | mazyr
# Processing Record 38 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 11 | nova olimpia
# Processing Record 40 of Set 11 | tiznit
# Processing Record 41 of Set 11 | jackson
# Processing Record 42 of Set 11 | edd
# Processing Record 43 of Set 11 | kasane
# Processing Record 44 of Set 11 | dunedin
# Processing Record 45 of Set 11 | sinnamary
# Processing Record 46 of Set 11 | scarborough
# Processing Record 47 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 11 | smithers
# Processing Record 49 of Set 11 | minggang
# Processing Record 50 of Set 11 | tautira
# Processing Record 1 of Set 12 | baffa
# Processing Record 2 of Set 12 | brae
# Processing Record 3 of Set 12 | morro bay
# Processing Record 4 of Set 12 | senno
# Processing Record 5 of Set 12 | snyder
# Processing Record 6 of Set 12 | olafsvik
# Processing Record 7 of Set 12 | baruun-urt
# Processing Record 8 of Set 12 | burica
# City not found. Skipping...
# Processing Record 9 of Set 12 | huarmey
# Processing Record 10 of Set 12 | port hedland
# Processing Record 11 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 12 | tilichiki
# Processing Record 13 of Set 12 | bandarbeyla
# Processing Record 14 of Set 12 | lixourion
# Processing Record 15 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 12 | is
# City not found. Skipping...
# Processing Record 17 of Set 12 | kisesa
# Processing Record 18 of Set 12 | nichinan
# Processing Record 19 of Set 12 | paamiut
# Processing Record 20 of Set 12 | lata
# Processing Record 21 of Set 12 | san jose de rio tinto
# Processing Record 22 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 23 of Set 12 | sindi
# Processing Record 24 of Set 12 | tres picos
# Processing Record 25 of Set 12 | mnogovershinnyy
# Processing Record 26 of Set 12 | ambilobe
# Processing Record 27 of Set 12 | kulhudhuffushi
# Processing Record 28 of Set 12 | cross lanes
# Processing Record 29 of Set 12 | san lorenzo
# Processing Record 30 of Set 12 | gambela
# Processing Record 31 of Set 12 | lhuntshi
# City not found. Skipping...
# Processing Record 32 of Set 12 | juniyah
# City not found. Skipping...
# Processing Record 33 of Set 12 | novaya igirma
# Processing Record 34 of Set 12 | zvishavane
# Processing Record 35 of Set 12 | nevel
# Processing Record 36 of Set 12 | noyabrsk
# Processing Record 37 of Set 12 | americus
# Processing Record 38 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 12 | abu dhabi
# Processing Record 40 of Set 12 | shache
# Processing Record 41 of Set 12 | whitianga
# Processing Record 42 of Set 12 | hualmay
# Processing Record 43 of Set 12 | cape canaveral
# Processing Record 44 of Set 12 | samarai
# Processing Record 45 of Set 12 | montabaur
# Processing Record 46 of Set 12 | trairi
# Processing Record 47 of Set 12 | mayor pablo lagerenza
# Processing Record 48 of Set 12 | banjar
# Processing Record 49 of Set 12 | alyangula
# Processing Record 50 of Set 12 | farafangana
# Processing Record 1 of Set 13 | ancud
# Processing Record 2 of Set 13 | esna
# Processing Record 3 of Set 13 | key west
# Processing Record 4 of Set 13 | san andres
# Processing Record 5 of Set 13 | kalmunai
# Processing Record 6 of Set 13 | lewiston
# Processing Record 7 of Set 13 | koksovyy
# Processing Record 8 of Set 13 | yulara
# Processing Record 9 of Set 13 | komsomolskiy
# Processing Record 10 of Set 13 | karaman
# Processing Record 11 of Set 13 | lufilufi
# Processing Record 12 of Set 13 | ovsyanka
# Processing Record 13 of Set 13 | burns lake
# Processing Record 14 of Set 13 | nurota
# Processing Record 15 of Set 13 | plettenberg bay
# Processing Record 16 of Set 13 | hami
# Processing Record 17 of Set 13 | phibun mangsahan
# Processing Record 18 of Set 13 | aguimes
# Processing Record 19 of Set 13 | port-cartier
# Processing Record 20 of Set 13 | la ronge
# Processing Record 21 of Set 13 | vestmannaeyjar
# Processing Record 22 of Set 13 | aswan
# Processing Record 23 of Set 13 | luwuk
# Processing Record 24 of Set 13 | shu
# Processing Record 25 of Set 13 | veraval
# Processing Record 26 of Set 13 | agadez
# Processing Record 27 of Set 13 | canita
# Processing Record 28 of Set 13 | asfi
# Processing Record 29 of Set 13 | chipinge
# Processing Record 30 of Set 13 | makanya
# Processing Record 31 of Set 13 | juruti
# Processing Record 32 of Set 13 | valparaiso
# Processing Record 33 of Set 13 | jurbarkas
# Processing Record 34 of Set 13 | la asuncion
# Processing Record 35 of Set 13 | port blair
# Processing Record 36 of Set 13 | lucea
# Processing Record 37 of Set 13 | galesong
# Processing Record 38 of Set 13 | laramie
# Processing Record 39 of Set 13 | zyryanka
# Processing Record 40 of Set 13 | belaya gora
# Processing Record 41 of Set 13 | batagay
# Processing Record 42 of Set 13 | fomboni
# Processing Record 43 of Set 13 | henties bay
# Processing Record 44 of Set 13 | flin flon
# Processing Record 45 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 13 | mercedes
# Processing Record 47 of Set 13 | bar harbor
# Processing Record 48 of Set 13 | kavaratti
# Processing Record 49 of Set 13 | severo-yeniseyskiy
# Processing Record 50 of Set 13 | blagoveshchenka
# Processing Record 1 of Set 14 | erzin
# Processing Record 2 of Set 14 | ranong
# Processing Record 3 of Set 14 | kattivakkam
# Processing Record 4 of Set 14 | talcher
# Processing Record 5 of Set 14 | aykhal
# Processing Record 6 of Set 14 | beyneu
# Processing Record 7 of Set 14 | neepawa
# Processing Record 8 of Set 14 | asosa
# Processing Record 9 of Set 14 | sorland
# Processing Record 10 of Set 14 | saint-georges
# Processing Record 11 of Set 14 | terrak
# Processing Record 12 of Set 14 | ilebo
# Processing Record 13 of Set 14 | berbera
# Processing Record 14 of Set 14 | svetlyy
# Processing Record 15 of Set 14 | ghanzi
# Processing Record 16 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 14 | bull savanna
# Processing Record 18 of Set 14 | arlit
# Processing Record 19 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 14 | pioner
# Processing Record 22 of Set 14 | antalaha
# Processing Record 23 of Set 14 | glendive
# Processing Record 24 of Set 14 | hokitika
# Processing Record 25 of Set 14 | winslow
# Processing Record 26 of Set 14 | porto novo
# Processing Record 27 of Set 14 | natal
# Processing Record 28 of Set 14 | tevriz
# Processing Record 29 of Set 14 | antofagasta
# Processing Record 30 of Set 14 | temir
# Processing Record 31 of Set 14 | neiafu
# Processing Record 32 of Set 14 | mabaruma
# Processing Record 33 of Set 14 | marathon
# Processing Record 34 of Set 14 | okato
# Processing Record 35 of Set 14 | aasiaat
# Processing Record 36 of Set 14 | bethanien
# Processing Record 37 of Set 14 | lhokseumawe
# Processing Record 38 of Set 14 | binga
# Processing Record 39 of Set 14 | matara
# Processing Record 40 of Set 14 | coihaique
# Processing Record 41 of Set 14 | bathsheba
# Processing Record 42 of Set 14 | kirakira
# Processing Record 43 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 44 of Set 14 | hurghada
# Processing Record 45 of Set 14 | taldan
# Processing Record 46 of Set 14 | dunda
# Processing Record 47 of Set 14 | ban nahin
# Processing Record 48 of Set 14 | pimentel
# Processing Record 49 of Set 14 | jumla
# Processing Record 50 of Set 14 | ayios kirikos
# City not found. Skipping...
# Processing Record 1 of Set 15 | shanghai
# Processing Record 2 of Set 15 | puerto leguizamo
# Processing Record 3 of Set 15 | kaohsiung
# Processing Record 4 of Set 15 | havelock
# Processing Record 5 of Set 15 | puerto carreno
# Processing Record 6 of Set 15 | hendijan
# City not found. Skipping...
# Processing Record 7 of Set 15 | ilinskiy
# Processing Record 8 of Set 15 | nefteyugansk
# Processing Record 9 of Set 15 | kanigoro
# Processing Record 10 of Set 15 | macklin
# Processing Record 11 of Set 15 | sarai alamgir
# Processing Record 12 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 13 of Set 15 | mirabad
# Processing Record 14 of Set 15 | havoysund
# Processing Record 15 of Set 15 | broome
# Processing Record 16 of Set 15 | whitehorse
# Processing Record 17 of Set 15 | moerai
# Processing Record 18 of Set 15 | cody
# Processing Record 19 of Set 15 | forecariah
# Processing Record 20 of Set 15 | san-pedro
# Processing Record 21 of Set 15 | freeport
# Processing Record 22 of Set 15 | puerto ayacucho
# Processing Record 23 of Set 15 | glyadyanskoye
# Processing Record 24 of Set 15 | celestun
# Processing Record 25 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 15 | shamkhal
# Processing Record 27 of Set 15 | aurangabad
# Processing Record 28 of Set 15 | darnah
# Processing Record 29 of Set 15 | saint-denis
# Processing Record 30 of Set 15 | pishin
# Processing Record 31 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 15 | cubuk
# Processing Record 33 of Set 15 | graneros
# Processing Record 34 of Set 15 | zhigansk
# Processing Record 35 of Set 15 | yanam
# Processing Record 36 of Set 15 | nuuk
# Processing Record 37 of Set 15 | bacabal
# Processing Record 38 of Set 15 | mackay
# Processing Record 39 of Set 15 | dakar
# Processing Record 40 of Set 15 | barraute
# Processing Record 41 of Set 15 | malinovoye ozero
# Processing Record 42 of Set 15 | pemberton
# Processing Record 43 of Set 15 | port-gentil
# Processing Record 44 of Set 15 | beloha
# Processing Record 45 of Set 15 | college
# Processing Record 46 of Set 15 | makinsk
# Processing Record 47 of Set 15 | kayerkan
# Processing Record 48 of Set 15 | chingirlau
# Processing Record 49 of Set 15 | kolondieba
# Processing Record 50 of Set 15 | araouane
# Processing Record 1 of Set 16 | potgietersrus
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Victor Harbor -35.5667  138.6167     62.01        73          22
# 1       Sobolevo  54.4299   31.8996     22.28        94         100
# 2      Yenisehir  40.2644   29.6531     39.25        81          75
# 3   Ponta Do Sol  32.6667  -17.1000     70.12        70          94
# 4        Northam  51.0333   -4.2167     51.42        93          85
# 5      Jamestown  42.0970  -79.2353     32.09        55         100
# 6        Ushuaia -54.8000  -68.3000     47.82        61          75
# 7       Cherskiy  68.7500  161.3000    -26.03        97           7
# 8   Punta Arenas -53.1500  -70.9167     50.02        53         100
# 9          Matay  28.4190   30.7792     58.53        42          44
#
#    Wind Speed          Weather Description Country
# 0        1.01                   few clouds      AU
# 1        9.66                         snow      RU
# 2        6.91  light intensity shower rain      TR
# 3        9.46              overcast clouds      PT
# 4       15.77              overcast clouds      GB
# 5       11.50                   light snow      US
# 6       16.11                broken clouds      AR
# 7        1.70                    clear sky      RU
# 8        6.91                   light rain      CL
# 9       16.15             scattered clouds      EG

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# %%
city_data_df=city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Victor Harbor      AU -35.5667  138.6167     62.01        73          22
# 1       Sobolevo      RU  54.4299   31.8996     22.28        94         100
# 2      Yenisehir      TR  40.2644   29.6531     39.25        81          75
# 3   Ponta Do Sol      PT  32.6667  -17.1000     70.12        70          94
# 4        Northam      GB  51.0333   -4.2167     51.42        93          85
# 5      Jamestown      US  42.0970  -79.2353     32.09        55         100
# 6        Ushuaia      AR -54.8000  -68.3000     47.82        61          75
# 7       Cherskiy      RU  68.7500  161.3000    -26.03        97           7
# 8   Punta Arenas      CL -53.1500  -70.9167     50.02        53         100
# 9          Matay      EG  28.4190   30.7792     58.53        42          44
#
#    Wind Speed          Weather Description
# 0        1.01                   few clouds
# 1        9.66                         snow
# 2        6.91  light intensity shower rain
# 3        9.46              overcast clouds
# 4       15.77              overcast clouds
# 5       11.50                   light snow
# 6       16.11                broken clouds
# 7        1.70                    clear sky
# 8        6.91                   light rain
# 9       16.15             scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
